# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import internet
# %matplotlib inline
sns.set_context("talk")

# %%
df = pd.DataFrame(internet.parse_file('thinkpad.txt'))
df.head()
# Out:
#                         date  download    ping  upload
# 0  2014-09-01 10:45:01-04:00     14.03  14.858    1.61
# 1  2014-09-01 11:00:01-04:00      2.02  88.791    0.70
# 2  2014-09-01 11:15:01-04:00     13.25   8.016    1.92
# 3  2014-09-01 11:30:01-04:00      8.21  21.097    1.74
# 4  2014-09-01 11:45:01-04:00      4.95  10.002    1.75
#
# [5 rows x 4 columns]

# %%
df.describe()
# Out:
#           download         ping       upload
# count  5508.000000  5508.000000  5508.000000
# mean     23.337885    24.852205     8.365773
# std      12.986287    43.253695    11.915341
# min       0.000000     2.182000     0.000000
# 25%      13.310000     7.636000     1.900000
# 50%      22.940000    13.006500     1.960000
# 75%      29.990000    27.047500    12.955000
# max      68.800000  1028.971000    84.250000
#
# [8 rows x 3 columns]

# %%
nonandf = df.fillna(method='pad')

# %%
sns.tsplot(df['ping']);

# %%
sns.tsplot(df['download']);

# %%
sns.tsplot(df['upload']);

# %%
sns.violinplot(nonandf[['download', 'upload']]);

# %%
sns.violinplot(nonandf['ping']);
